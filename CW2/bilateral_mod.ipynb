# %%
# # Loop through all the pixels in the image
#     for x in range(image.shape[0]):
#         for y in range(image.shape[1]):
#             for z in range(image.shape[2]):
#                 # Get the pixel value at (x, y, z)
#                 center_pixel = image[x, y, z]

#                 # Initialize the weight sum
#                 weight_sum = 0

#                 # Loop through the local neighborhood
#                 for i in range(-diameter, diameter + 1):
#                     for j in range(-diameter, diameter + 1):
#                         for k in range(-diameter, diameter + 1):
#                             # Get the coordinates of the neighbor
#                             neighbor_x = x + i
#                             neighbor_y = y + j
#                             neighbor_z = z + k

#                             # Make sure the neighbor is inside the image
#                             if 0 <= neighbor_x < image.shape[0] and \
#                                0 <= neighbor_y < image.shape[1] and \
#                                0 <= neighbor_z < image.shape[2]:

#                                 # Get the pixel value of the neighbor
#                                 neighbor_pixel = image[neighbor_x, neighbor_y, neighbor_z]

#                                 # Calculate the spatial distance
#                                 spatial_distance = (i ** 2 + j ** 2 + k ** 2) ** 0.5

#                                 # Calculate the intensity difference
#                                 intensity_distance = abs(center_pixel - neighbor_pixel)

#                                 # Calculate the weight
#                                 weight = np.exp(-((spatial_distance ** 2) / (2 * sigma_spatial ** 2) + (intensity_distance ** 2) / (2 * sigma_intensity ** 2)))

#                                 # Accumulate the filtered value
#                                 filtered_image[x, y, z] += neighbor_pixel * weight

#                                 # Accumulate the weights
#                                 weight_sum += weight

#                 # Divide by the sum of the weights to get the average
#                 filtered_image[x, y, z] /= weight_sum

# %%
# # A bilateral filter is a non-linear, edge preserving and noise reducing smoothing filter for images.
# **It replaces the intensity of each pixel with a weighted average of intensity values from nearby pixels.**

# - This weight can be based on a Gaussian distribution.
# - The weight does not only depend on the Euclidean distance of pixels, but also on the radiometric differences e.g color intensity 
# - The Gaussian distribution is used to give more weight to pixels that are closer to the central pixel and also have similar intensity values.

# Therefore, To implement a bilateral filter from scratch that filters a 3D image without having to take individual 2D slices,
# we can use a nested loop to iterate through each pixel in the 3D image,
# and then use the intensity and spatial distance of the pixel to compute the weight of the pixel.

import numpy as np

def bilateral_filter_3d(image, diameter, sigma_intensity, sigma_spatial):
    """Apply a bilateral filter to an image.
    Parameters
    ----------
    image : ndarray
        Input image.
    diameter : int
        Diameter of each pixel neighborhood that is used during filtering.
    sigma_intensity : float
        Filter sigma in the color/intensity range space.
    sigma_spatial : float
        Filter sigma in the coordinate space.
    Returns
    -------
    filtered_image : ndarray
        Filtered output image.
    """
    # Create an empty image to store the output
    filtered_image = np.zeros_like(image)
    
    # Loop through all the pixels in the image
    for x in range(image.shape[0]):
        for y in range(image.shape[1]):
            for z in range(image.shape[2]):
                # Get the pixel value at (x, y, z)
                center_pixel = image[x, y, z]

                # Initialize the weight sum
                neighborhood_sum = 0
                neighborhood_weight_sum = 0
                weight_sum = 0
                
                # Loop through the local neighborhood
                for x_n in range(x-diameter, x+diameter + 1):
                    for y_n in range(y-diameter, y+diameter + 1):
                        for z_n in range(z-diameter, z+diameter + 1):
                            # Get the coordinates of the neighbour
                            neighbor_x = x_n
                            neighbor_y = y_n
                            neighbor_z = z_n

                            # Make sure the neighbor is inside the image
                            if 0 <= neighbor_x < image.shape[0] and \
                                0 <= neighbor_y < image.shape[1] and \
                                0 <= neighbor_z < image.shape[2]:

                                # Get the pixel value of the neighbor
                                neighbor_pixel = image[neighbor_x, neighbor_y, neighbor_z]

                                # Calculate the spatial distance
                                spatial_distance = ((x-x_n) ** 2 + (y-y_n) ** 2 + (z-z_n) ** 2) ** 0.5
                                
                                # Calculate the intensity difference
                                intensity_distance = (center_pixel - neighbor_pixel)

                                # Calculate the intensity weight i.e the weight of the pixel based on the intensity difference
                                intensity_weight = (1.0/(2*np.pi*(sigma_intensity**2)))*np.exp(-(intensity_distance**2) / (2*sigma_intensity**2))

                                # Calculate the spatial weight i.e the weight of the pixel based on the spatial distance from the center pixel
                                spatial_weight = (1.0/(2*np.pi*(sigma_spatial**2)))*np.exp(-(spatial_distance**2) / (2*sigma_spatial**2))

                                # Calculate the overall weight by multiplying: spatial weight * intensity weight
                                # Compute the overall weight
                                weight = spatial_weight * intensity_weight

                                # Accumulate the weights 
                                weight_sum += weight

                                # Accumulate the weighted neighborhood sum ie the weighted sum of all the pixels in the neighborhood
                                neighborhood_sum += weight * image[x_n, y_n, z_n]

                                # Accumulate the neighborhood weight sum ie the sum of all the weights
                                neighborhood_weight_sum += weight
        
                # Compute the filtered pixel value
                filtered_image[x, y, z] = neighborhood_sum / neighborhood_weight_sum
    # Return the filtered image
    return filtered_image

# %%
# # A bilateral filter is a non-linear, edge preserving and noise reducing smoothing filter for images.
# **It replaces the intensity of each pixel with a weighted average of intensity values from nearby pixels.**

# - This weight can be based on a Gaussian distribution.
# - The weight does not only depend on the Euclidean distance of pixels, but also on the radiometric differences e.g color intensity 
# - The Gaussian distribution is used to give more weight to pixels that are closer to the central pixel and also have similar intensity values.

# Therefore, To implement a bilateral filter from scratch that filters a 3D image without having to take individual 2D slices,
# we can use a nested loop to iterate through each pixel in the 3D image,
# and then use the intensity and spatial distance of the pixel to compute the weight of the pixel.

import numpy as np
# Modify code for 2D image
def bilateral_filter_2d(image, diameter, sigma_intensity, sigma_spatial):
    """Apply a bilateral filter to an image.
    Parameters
    ----------
    image : ndarray
        Input image.
    diameter : int
        Diameter of each pixel neighborhood that is used during filtering.
    sigma_intensity : float
        Filter sigma in the color/intensity range space.
    sigma_spatial : float
        Filter sigma in the coordinate space.
    Returns
    -------
    filtered_image : ndarray
        Filtered output image.
    """
    # Create an empty image to store the output
    filtered_image = np.zeros_like(image)
    
    # Loop through all the pixels in the image
    for x in range(image.shape[0]):
        for y in range(image.shape[1]):
        #for z in range(image.shape[2]):
            # Get the pixel value at (x, y, z)
            center_pixel = image[x, y]

            # Initialize the weight sum
            neighborhood_sum = 0
            neighborhood_weight_sum = 0
            weight_sum = 0
            
            # Loop through the local neighborhood
            for x_n in range(x-diameter, x+diameter + 1):
                for y_n in range(y-diameter, y+diameter + 1):
                    #for z_n in range(-diameter, diameter + 1):
                    # Get the coordinates of the neighbour
                    neighbor_x = x_n
                    neighbor_y = y_n
                    #neighbor_z = z + z_n

                    # Make sure the neighbor is inside the image
                    if 0 <= neighbor_x < image.shape[0] and 0 <= neighbor_y < image.shape[1]:

                        # Get the pixel value of the neighbor
                        neighbor_pixel = image[neighbor_x, neighbor_y]

                        # Calculate the spatial distance
                        spatial_distance = ((x-x_n) ** 2 + (y-y_n) ** 2) ** 0.5
                        
                        # Calculate the intensity difference
                        intensity_distance = (center_pixel - neighbor_pixel)

                        # Calculate the intensity weight i.e the weight of the pixel based on the intensity difference
                        intensity_weight = (1.0/(2*np.pi*(sigma_intensity**2)))*np.exp(-(intensity_distance**2) / (2*sigma_intensity**2))

                        # Calculate the spatial weight i.e the weight of the pixel based on the spatial distance from the center pixel
                        spatial_weight = (1.0/(2*np.pi*(sigma_spatial**2)))*np.exp(-(spatial_distance**2) / (2*sigma_spatial**2))

                        # Calculate the overall weight by multiplying: spatial weight * intensity weight
                        # Compute the overall weight
                        weight = spatial_weight * intensity_weight

                        # Accumulate the weights 
                        weight_sum += weight

                        # Accumulate the weighted neighborhood sum ie the weighted sum of all the pixels in the neighborhood
                        neighborhood_sum += weight * image[x_n, y_n]

                        # Accumulate the neighborhood weight sum ie the sum of all the weights
                        neighborhood_weight_sum += weight
        
            # Compute the filtered pixel value
            filtered_image[x, y] = neighborhood_sum / neighborhood_weight_sum

    return filtered_image

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = np.load("test_trus.npy").T
print("Image shape:", image.shape)

# Apply bilateral filter to image using OpenCV
d = 3
sigmaColor = 40
sigmaSpace = 10
# Apply bilateral filter to image using bilateral_filter_2d
filtered_image_2d = bilateral_filter_2d(image[:, :, 0], d, sigmaColor, sigmaSpace)
plt.imshow(filtered_image_2d, cmap='gray')
# Out:
# Image shape: (455, 325, 46)
# /tmp/ipykernel_19657/87517354.py:65: RuntimeWarning: overflow encountered in ubyte_scalars
#   intensity_distance = (center_pixel - neighbor_pixel)

# %%
filtered_image_2d.shape
# Out:
# (455, 325)

# %%
# Apply bilateral filter to image using bilateral_filter_3d
filtered_image_3d = bilateral_filter_3d(image[:, :, :2], d, sigmaColor, sigmaSpace)
plt.imshow(filtered_image_3d[:, :, 0], cmap='gray')

# %%
plt.imshow(filtered_image_3d[:, :, 0], cmap='gray')

# %%
fil

# %%
import cv2
import numpy as np

# Apply bilateral filter to image using OpenCV
d = 3
sigmaColor = 75
sigmaSpace = 5
filtered_image = cv2.bilateralFilter(image[:, :, 0], d, sigmaColor, sigmaSpace)

# Apply bilateral filter to image using bilateral_filter_2d
filtered_image_2d = bilateral_filter_2d(image[:, :, 0], d, sigmaColor, sigmaSpace)

# Apply bilateral filter to image using bilateral_filter_3d
filtered_image_3d = bilateral_filter_3d(image[:, :, :2], d, sigmaColor, sigmaSpace)


import matplotlib.pyplot as plt
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(10, 5))
ax1.imshow(image[:,:,1], cmap='gray')
ax1.set_title('Original')
ax2.imshow(filtered_image, cmap='gray')
ax2.set_title('cv2')
ax3.imshow(filtered_image_2d, cmap='gray')
ax3.set_title('2d')
ax4.imshow(filtered_image_3d[:,:,0], cmap='gray')
ax4.set_title('3d')
# Out:
# /tmp/ipykernel_19657/87517354.py:65: RuntimeWarning: overflow encountered in ubyte_scalars
#   intensity_distance = (center_pixel - neighbor_pixel)
# /tmp/ipykernel_19657/2958091240.py:67: RuntimeWarning: overflow encountered in ubyte_scalars
#   intensity_distance = (center_pixel - neighbor_pixel)
# Text(0.5, 1.0, '3d')

# %%
image[:, :, :1].shape
# Out:
# (455, 325, 1)

# %%
import numpy as np
from scipy.ndimage.filters import gaussian_filter

def bilateral_filter_2d(img, d, sigmaColor, sigmaSpace):
    filtered_img = np.zeros_like(img)
    for x in range(img.shape[0]):
        for y in range(img.shape[1]):
            #for x in range(img.shape[2]):
                # Compute the Gaussian spatial weight
            #spatial_weight = np.exp(-(x**2 + y**2) / (2*sigmaSpace**2))
            
            # Iterate through the neighborhood
            neighborhood_sum = 0
            neighborhood_weight_sum = 0
            for x_n in range(x-d, x+d+1):
                for y_n in range(y-d, y+d+1):
                    #for x_n in range(x-d, x+d+1):
                    # Check if the neighborhood pixel is within the image bounds
                    if ((0 <= x_n < img.shape[0]) and (0 <= y_n < img.shape[1])):
                        # Compute the Gaussian intensity weight
                        intensity_weight = (1.0/(2*np.pi*(sigmaColor**2)))*np.exp(-(img[x_n, y_n] - img[x, y])**2 / (2*sigmaColor**2))
                        spatial_weight = (1.0/(2*np.pi*(sigmaSpace**2)))*np.exp(-(np.sqrt((x - x_n) ** 2 + (y - y_n) ** 2))**2 / (2*sigmaSpace**2))
                        
                        # Compute the overall weight
                        weight = spatial_weight * intensity_weight
                        
                        #Accumulate the weighted neighborhood sum
                        neighborhood_sum += weight * img[x_n, y_n]
                        neighborhood_weight_sum += weight
        
            # Compute the filtered pixel value
            filtered_img[x, y] = neighborhood_sum / neighborhood_weight_sum

    return filtered_img
# Out:
# /tmp/ipykernel_907/513580587.py:2: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
import cv2
import numpy as np

# Apply bilateral filter to image using OpenCV
d = 30
sigmaColor = 5
sigmaSpace = 5
filtered_image = cv2.bilateralFilter(image[:, :, 0], d, sigmaColor, sigmaSpace)
plt.imshow(filtered_image, cmap='gray')

# %% [markdown]
# ## 2D filtering after re-slicing

# %% [markdown]
# ### Apply re-slicing

# %%
import numpy as np
import matplotlib.pyplot as plt
image = np.load("test_trus.npy").T

# Import interpn
from scipy.interpolate import interpn

# Apply rotation at the centre of the slice
translation_points = (np.array(image[:, :, 0].shape) - 1)/2
rotation_angle = 45

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the 3D volume of the prostate glandprostate_volume = np.load("prostate_volume.npy")
# Load the 3D volume of the prostate gland
prostate_volume = image

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Set the x, y, and z limits of the plot
x_len, y_len, z_len = prostate_volume.shape
ax.set_xlim(0, x_len)
ax.set_ylim(0, y_len)
ax.set_zlim(0, z_len)

# Define the transformation matrix for the oblique view
theta = np.deg2rad(0)
phi = np.deg2rad(-25)
slice_index = 0
# translation_matrix = np.array([[1, 0, -translation_points[0]],
#                                    [0, 1, -translation_points[1]],
#                                    [0, 0, 1]])
# rotation_matrix_theta = np.array([[np.cos(theta), -np.sin(theta), 0],
#                             [np.sin(theta), np.cos(theta), 0],
#                             [0, 0, 1]])
# rotation_matrix_phi = np.array([[1, 0, 0],
#                                    [0, np.cos(phi), -np.sin(phi)],
#                                    [0, np.sin(phi), np.cos(phi)]])
# # Then apply translation back to the original position
# translation_back_matrix = np.array([[1, 0, translation_points[0]],
#                                     [0, 1, translation_points[1]],
#                                     [0, 0, 1]])
# # Create a composed affine matrix
# rotation_matrix = np.matmul(translation_back_matrix, np.matmul(rotation_matrix_phi, np.matmul(rotation_matrix_theta, translation_matrix)))


rotation_matrix_theta = np.array([[np.cos(theta), -np.sin(theta), 0],
                            [np.sin(theta), np.cos(theta), 0],
                            [0, 0, 1]])
rotation_matrix_phi = np.array([[1, 0, 0],
                                   [0, np.cos(phi), -np.sin(phi)],
                                   [0, np.sin(phi), np.cos(phi)]])

# Create a composed affine matrix
rotation_matrix = np.matmul(rotation_matrix_phi, rotation_matrix_theta)


# Define the coordinates of the slice

xx, yy = np.meshgrid(np.arange(x_len), np.arange(y_len), indexing='ij')
zz = np.ones_like(xx) * slice_index


# Apply the transformation matrix to the coordinates
xyz = np.vstack((xx.flatten(), yy.flatten(), zz.flatten())).T
xyz = np.dot(xyz, rotation_matrix)

# Reshape the transformed coordinates and the slice values
xx, yy, zz = xyz[:, 0].reshape(xx.shape), xyz[:, 1].reshape(yy.shape), xyz[:, 2].reshape(zz.shape)



# Extract the slice values
slice_values = prostate_volume[:, :, slice_index]


# Interpolate the slice values to the transformed coordinates
slice_values = interpn((np.arange(x_len), np.arange(y_len)), slice_values, np.vstack((xx.flatten(), yy.flatten())).T, method='nearest', bounds_error=False, fill_value=None)

# Plot the transformed slice as a surface

# Create a 1D array of the slice values
color_values = slice_values.flatten()

# Create a 1D array of RGB colors corresponding to the intensity values
cmap = plt.cm.gray
norm = plt.Normalize(vmin=color_values.min(), vmax=color_values.max())
color_array = cmap(norm(color_values))

# Plot the transformed slice as a 3D scatter plot
ax.scatter(xx, yy, zz, c=color_array, s = 0.07)

# Calculate the minimum and maximum z-coordinates of the transformed slice
z_min = zz.min()
z_max = zz.max()
x_min = xx.min()
x_max = xx.max()
y_min = yy.min()
y_max = yy.max()

# Set the limits of the z-axis to include the entire slice
ax.set_zlim(z_min, z_max)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)

# Set the title of the plot
ax.set_title("Oblique view of a prostate gland 3D volume slice")

# Set the labels for the x, y, and z axes
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

# Show the plot
plt.show()

# %%
re_sliced_image = slice_values.reshape(xx.shape)
re_sliced_image.shape
import numpy as np
import matplotlib.pyplot as plt


# Load image
image = np.load("test_trus.npy").T
print("Image shape:", image.shape)
print("re_sliced_image:", re_sliced_image.shape)
# Out:
# Image shape: (455, 325, 46)
# re_sliced_image: (455, 325)

# %% [markdown]
# ### Apply 2D filtering after re-slicing

# %% [markdown]
# 1. What is the effect of increasing sigmaColor in bilateral filters?5, 20, 80
# 1. What is the effect of increasing sigmaSpace in bilateral filters?5, 20, 80

# %%
# Apply bilateral filter to image using OpenCV
d = 3
sigmaColor = 5
sigmaSpace = 5
# Apply bilateral filter to image using bilateral_filter_2d
filtered_image_2d = bilateral_filter_2d(re_sliced_image, d, sigmaColor, sigmaSpace)
#plt.imshow(filtered_image_2d, cmap='gray')

# # Create a 1D array of the slice values
# # Fill in the blanks with 0s
# xx2d = xx
# yy2d = yy
# plt.scatter(xx2d, yy2d, c=color_array, s = 0.07)
# # Add title
# plt.title("2D filtering | d = 3, sigmaColor = 120, sigmaSpace = 5")
# # Save the figure
# plt.savefig("2d_filtering_sigmaColor_120.png")

# %%
# # Create function that applies filter to image then saves the plot
# def plot_filtered_image(image, d, sigmaColor, sigmaSpace):
#     # Apply bilateral filter to image using bilateral_filter_2d
#     filtered_image_2d = bilateral_filter_2d(image, d, sigmaColor, sigmaSpace)
#     # Create a 1D array of the slice values
#     color_values = filtered_image_2d.flatten()
#     # Create a 1D array of RGB colors corresponding to the intensity values
#     cmap = plt.cm.gray
#     norm = plt.Normalize(vmin=color_values.min(), vmax=color_values.max())
#     color_array = cmap(norm(color_values))
#     # Create a 2D array of the x and y coordinates
#     xx2d, yy2d = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]), indexing='ij')
#     # Plot the filtered image as a 3D scatter plot
#     plt.scatter(xx2d, yy2d, c=color_array, s = 0.07)
#     # Add title
#     plt.title("2D filtering | d = {}, sigmaColor = {}, sigmaSpace = {}".format(d, sigmaColor, sigmaSpace))
#     # Save the figure
#     plt.savefig("2d_filtering_d_{}_sigmaColor_{}_sigmaSpace_{}.png".format(d, sigmaColor, sigmaSpace))
#     # Clear the plot
#     plt.clf()

# %% [markdown]
# ### Difference between the re-sliced then filtered image and the original image

# %%
# Install skimage version 0.19
# !pip install scikit-image==0.19
# Out:
# Collecting scikit-image==0.19
#   Downloading scikit-image-0.19.0.tar.gz (30.1 MB)
#      --------------------------------------- 30.1/30.1 MB 14.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.17.0 in c:\users\homeuser\onedrive - university college london\mres\programming_foundations\bs\lib\site-packages (from scikit-image==0.19) (1.24.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\homeuser\onedrive - university college london\mres\programming_foundations\bs\lib\site-packages (from scikit-image==0.19) (1.10.0)
# Collecting networkx>=2.2
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\homeuser\onedrive - university college london\mres\programming_foundations\bs\lib\site-packages (from scikit-image==0.19) (9.4.0)
# Collecting imageio>=2.4.1
#   Using cached imageio-2.25.1-py3-none-any.whl (3.4 MB)
# Collecting tifffile>=2019.7.26
#   Using cached tifffile-2023.2.3-py3-none-any.whl (215 kB)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp311-cp311-win_amd64.whl (4.2 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\homeuser\onedrive - university college london\mres\programming_foundations\bs\lib\site-packages (from scikit-image==0.19) (23.0)
# Building wheels for collected packages: scikit-image
#   Building wheel for scikit-image (pyproject.toml): started
#   Building wheel for scikit-image (pyproject.toml): finished with status 'error'
# Failed to build scikit-image
#   error: subprocess-exited-with-error
#
#   × Building wheel for scikit-image (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1044 lines of output]
#       <string>:9: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#       C:\Users\homeuser\AppData\Local\Temp\pip-build-env-wtw4jv5v\overlay\Lib\site-packages\setuptools\config\setupcfg.py:520: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#         warnings.warn(msg, warning_class)
#       Partial import of skimage during the build process.
#       Compiling C:\Users\homeuser\AppData\Local\Temp\pip-install-77rt0zxl\scikit-image_5815c097bdf048788edc4a1358d2e28f\skimage\morphology\_skeletonize_3d_cy.pyx because it changed.
#       [1/1] Cythonizing C:\Users\homeuser\AppData\Local\Temp\pip-install-77rt0zxl\scikit-image_5815c097bdf048788edc4a1358d2e28f\skimage\morphology\_skeletonize_3d_cy.pyx
#       running bdist_wheel
#       running build
#       running config_cc
#       INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       INFO: build_src
#       INFO: building extension "skimage._shared.geometry" sources
#       INFO: building extension "skimage._shared.transform" sources
#       INFO: building extension "skimage._shared.interpolation" sources
#       INFO: building extension "skimage._shared.fast_exp" sources
#       INFO: building extension "skimage.draw._draw" sources
#       INFO: building extension "skimage.feature._cascade" sources
#       INFO: building extension "skimage.feature.corner_cy" sources
#       INFO: building extension "skimage.feature.censure_cy" sources
#       INFO: building extension "skimage.feature.orb_cy" sources
#       INFO: building extension "skimage.feature._texture" sources
#       INFO: building extension "skimage.feature._hoghistogram" sources
#       INFO: building extension "skimage.feature._haar" sources
#       INFO: building extension "skimage.feature._sift" sources
#       INFO: building extension "skimage.feature.brief_cy" sources
#       INFO: building extension "skimage.feature._hessian_det_appx" sources
#       INFO: building extension "skimage.restoration._unwrap_1d" sources
#       INFO: building extension "skimage.restoration._unwrap_2d" sources
#       INFO: building extension "skimage.restoration._unwrap_3d" sources
#       INFO: building extension "skimage.restoration._denoise_cy" sources
#       INFO: building extension "skimage.restoration._nl_means_denoising" sources
#       INFO: building extension "skimage.restoration._rolling_ball_cy" sources
#       INFO: building extension "skimage.restoration._inpaint" sources
#       INFO: building extension "skimage.filters.rank.core_cy" sources
#       INFO: building extension "skimage.filters.rank.core_cy_3d" sources
#       INFO: building extension "skimage.filters._multiotsu" sources
#       INFO: building extension "skimage.filters.rank.generic_cy" sources
#       INFO: building extension "skimage.filters.rank.percentile_cy" sources
#       INFO: building extension "skimage.filters.rank.bilateral_cy" sources
#       INFO: building extension "skimage.future.graph._ncut_cy" sources
#       INFO: building extension "skimage.graph._spath" sources
#       INFO: building extension "skimage.graph._mcp" sources
#       INFO: building extension "skimage.graph.heap" sources
#       INFO: building extension "skimage.io._plugins._colormixer" sources
#       INFO: building extension "skimage.io._plugins._histograms" sources
#       INFO: building extension "skimage.measure._ccomp" sources
#       INFO: building extension "skimage.measure._find_contours_cy" sources
#       INFO: building extension "skimage.measure._moments_cy" sources
#       INFO: building extension "skimage.measure._marching_cubes_classic_cy" sources
#       INFO: building extension "skimage.measure._marching_cubes_lewiner_cy" sources
#       INFO: building extension "skimage.measure._pnpoly" sources
#       INFO: building extension "skimage.morphology._skeletonize_cy" sources
#       INFO: building extension "skimage.morphology._convex_hull" sources
#       INFO: building extension "skimage.morphology._grayreconstruct" sources
#       INFO: building extension "skimage.morphology._max_tree" sources
#       INFO: building extension "skimage.morphology._skeletonize_3d_cy" sources
#       INFO: building extension "skimage.morphology._extrema_cy" sources
#       INFO: building extension "skimage.morphology._flood_fill_cy" sources
#       INFO: building extension "skimage.transform._hough_transform" sources
#       INFO: building extension "skimage.transform._warps_cy" sources
#       INFO: building extension "skimage.transform._radon_transform" sources
#       INFO: building extension "skimage.util._remap" sources
#       INFO: building extension "skimage.segmentation._watershed_cy" sources
#       INFO: building extension "skimage.segmentation._felzenszwalb_cy" sources
#       INFO: building extension "skimage.segmentation._quickshift_cy" sources
#       INFO: building extension "skimage.segmentation._slic" sources
#       INFO: building data_files sources
#       INFO: build_src: building npy-pkg config files
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\skimage
#       copying skimage\conftest.py -> build\lib.win-amd64-cpython-311\skimage
#       copying skimage\setup.py -> build\lib.win-amd64-cpython-311\skimage
#       copying skimage\_build.py -> build\lib.win-amd64-cpython-311\skimage
#       copying skimage\__init__.py -> build\lib.win-amd64-cpython-311\skimage
#       creating build\lib.win-amd64-cpython-311\doc
#       creating build\lib.win-amd64-cpython-311\doc\ext
#       copying doc\ext\doi_role.py -> build\lib.win-amd64-cpython-311\doc\ext
#       copying doc\ext\notebook_doc.py -> build\lib.win-amd64-cpython-311\doc\ext
#       copying doc\ext\plot2rst.py -> build\lib.win-amd64-cpython-311\doc\ext
#       copying doc\ext\__init__.py -> build\lib.win-amd64-cpython-311\doc\ext
#       creating build\lib.win-amd64-cpython-311\doc\ext\tests
#       copying doc\ext\tests\test_notebook_doc.py -> build\lib.win-amd64-cpython-311\doc\ext\tests
#       copying doc\ext\tests\__init__.py -> build\lib.win-amd64-cpython-311\doc\ext\tests
#       creating build\lib.win-amd64-cpython-311\skimage\color
#       copying skimage\color\adapt_rgb.py -> build\lib.win-amd64-cpython-311\skimage\color
#       copying skimage\color\colorconv.py -> build\lib.win-amd64-cpython-311\skimage\color
#       copying skimage\color\colorlabel.py -> build\lib.win-amd64-cpython-311\skimage\color
#       copying skimage\color\delta_e.py -> build\lib.win-amd64-cpython-311\skimage\color
#       copying skimage\color\rgb_colors.py -> build\lib.win-amd64-cpython-311\skimage\color
#       copying skimage\color\__init__.py -> build\lib.win-amd64-cpython-311\skimage\color
#       creating build\lib.win-amd64-cpython-311\skimage\data
#       copying skimage\data\setup.py -> build\lib.win-amd64-cpython-311\skimage\data
#       copying skimage\data\_binary_blobs.py -> build\lib.win-amd64-cpython-311\skimage\data
#       copying skimage\data\_fetchers.py -> build\lib.win-amd64-cpython-311\skimage\data
#       copying skimage\data\_registry.py -> build\lib.win-amd64-cpython-311\skimage\data
#       copying skimage\data\__init__.py -> build\lib.win-amd64-cpython-311\skimage\data
#       creating build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\draw.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\draw3d.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\draw_nd.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\setup.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\_polygon2mask.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\_random_shapes.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       copying skimage\draw\__init__.py -> build\lib.win-amd64-cpython-311\skimage\draw
#       creating build\lib.win-amd64-cpython-311\skimage\exposure
#       copying skimage\exposure\exposure.py -> build\lib.win-amd64-cpython-311\skimage\exposure
#       copying skimage\exposure\histogram_matching.py -> build\lib.win-amd64-cpython-311\skimage\exposure
#       copying skimage\exposure\setup.py -> build\lib.win-amd64-cpython-311\skimage\exposure
#       copying skimage\exposure\_adapthist.py -> build\lib.win-amd64-cpython-311\skimage\exposure
#       copying skimage\exposure\__init__.py -> build\lib.win-amd64-cpython-311\skimage\exposure
#       creating build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\blob.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\brief.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\brief_pythran.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\censure.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\corner.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\haar.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\match.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\orb.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\peak.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\setup.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\sift.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\template.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\texture.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\util.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\_basic_features.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\_canny.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\_daisy.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\_hessian_det_appx_pythran.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\_hog.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\_orb_descriptor_positions.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       copying skimage\feature\__init__.py -> build\lib.win-amd64-cpython-311\skimage\feature
#       creating build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\edges.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\lpi_filter.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\ridges.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\setup.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\thresholding.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_fft_based.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_gabor.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_gaussian.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_median.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_rank_order.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_sparse.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_unsharp_mask.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\_window.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       copying skimage\filters\__init__.py -> build\lib.win-amd64-cpython-311\skimage\filters
#       creating build\lib.win-amd64-cpython-311\skimage\future
#       copying skimage\future\manual_segmentation.py -> build\lib.win-amd64-cpython-311\skimage\future
#       copying skimage\future\setup.py -> build\lib.win-amd64-cpython-311\skimage\future
#       copying skimage\future\trainable_segmentation.py -> build\lib.win-amd64-cpython-311\skimage\future
#       copying skimage\future\__init__.py -> build\lib.win-amd64-cpython-311\skimage\future
#       creating build\lib.win-amd64-cpython-311\skimage\graph
#       copying skimage\graph\mcp.py -> build\lib.win-amd64-cpython-311\skimage\graph
#       copying skimage\graph\setup.py -> build\lib.win-amd64-cpython-311\skimage\graph
#       copying skimage\graph\spath.py -> build\lib.win-amd64-cpython-311\skimage\graph
#       copying skimage\graph\_graph.py -> build\lib.win-amd64-cpython-311\skimage\graph
#       copying skimage\graph\__init__.py -> build\lib.win-amd64-cpython-311\skimage\graph
#       creating build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\collection.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\manage_plugins.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\setup.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\sift.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\util.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\_image_stack.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\_io.py -> build\lib.win-amd64-cpython-311\skimage\io
#       copying skimage\io\__init__.py -> build\lib.win-amd64-cpython-311\skimage\io
#       creating build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\block.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\entropy.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\fit.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\pnpoly.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\profile.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\setup.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_blur_effect.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_find_contours.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_label.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_marching_cubes_classic.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_marching_cubes_lewiner.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_marching_cubes_lewiner_luts.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_moments.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_polygon.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_regionprops.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\_regionprops_utils.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       copying skimage\measure\__init__.py -> build\lib.win-amd64-cpython-311\skimage\measure
#       creating build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\set_metrics.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\simple_metrics.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\_adapted_rand_error.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\_contingency_table.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\_structural_similarity.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\_variation_of_information.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       copying skimage\metrics\__init__.py -> build\lib.win-amd64-cpython-311\skimage\metrics
#       creating build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\binary.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\convex_hull.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\extrema.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\footprints.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\gray.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\grayreconstruct.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\grey.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\greyreconstruct.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\max_tree.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\misc.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\selem.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\setup.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\_flood_fill.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\_skeletonize.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\_util.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       copying skimage\morphology\__init__.py -> build\lib.win-amd64-cpython-311\skimage\morphology
#       creating build\lib.win-amd64-cpython-311\skimage\registration
#       copying skimage\registration\_masked_phase_cross_correlation.py -> build\lib.win-amd64-cpython-311\skimage\registration
#       copying skimage\registration\_optical_flow.py -> build\lib.win-amd64-cpython-311\skimage\registration
#       copying skimage\registration\_optical_flow_utils.py -> build\lib.win-amd64-cpython-311\skimage\registration
#       copying skimage\registration\_phase_cross_correlation.py -> build\lib.win-amd64-cpython-311\skimage\registration
#       copying skimage\registration\__init__.py -> build\lib.win-amd64-cpython-311\skimage\registration
#       creating build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\deconvolution.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\inpaint.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\j_invariant.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\non_local_means.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\rolling_ball.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\setup.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\uft.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\unwrap.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_cycle_spin.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_denoise.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\__init__.py -> build\lib.win-amd64-cpython-311\skimage\restoration
#       creating build\lib.win-amd64-cpython-311\skimage\scripts
#       copying skimage\scripts\skivi.py -> build\lib.win-amd64-cpython-311\skimage\scripts
#       copying skimage\scripts\__init__.py -> build\lib.win-amd64-cpython-311\skimage\scripts
#       creating build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\active_contour_model.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\boundaries.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\morphsnakes.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\random_walker_segmentation.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\setup.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\slic_superpixels.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_chan_vese.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_clear_border.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_expand_labels.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_felzenszwalb.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_join.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_quickshift.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_watershed.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\__init__.py -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       creating build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\finite_radon_transform.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\hough_transform.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\integral.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\pyramids.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\radon_transform.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\setup.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_geometric.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_warps.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\__init__.py -> build\lib.win-amd64-cpython-311\skimage\transform
#       creating build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\apply_parallel.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\arraycrop.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\compare.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\dtype.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\lookfor.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\noise.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\setup.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\shape.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\unique.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\_invert.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\_label.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\_map_array.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\_montage.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\_regular_grid.py -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\__init__.py -> build\lib.win-amd64-cpython-311\skimage\util
#       creating build\lib.win-amd64-cpython-311\skimage\viewer
#       copying skimage\viewer\qt.py -> build\lib.win-amd64-cpython-311\skimage\viewer
#       copying skimage\viewer\__init__.py -> build\lib.win-amd64-cpython-311\skimage\viewer
#       creating build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\coord.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\filters.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\lazy.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\setup.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\tester.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\testing.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\utils.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\version_requirements.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\_dependency_checks.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\_geometry.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\_tempfile.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\_warnings.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\__init__.py -> build\lib.win-amd64-cpython-311\skimage\_shared
#       creating build\lib.win-amd64-cpython-311\skimage\color\tests
#       copying skimage\color\tests\test_adapt_rgb.py -> build\lib.win-amd64-cpython-311\skimage\color\tests
#       copying skimage\color\tests\test_colorconv.py -> build\lib.win-amd64-cpython-311\skimage\color\tests
#       copying skimage\color\tests\test_colorlabel.py -> build\lib.win-amd64-cpython-311\skimage\color\tests
#       copying skimage\color\tests\test_delta_e.py -> build\lib.win-amd64-cpython-311\skimage\color\tests
#       copying skimage\color\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\color\tests
#       creating build\lib.win-amd64-cpython-311\skimage\data\tests
#       copying skimage\data\tests\test_data.py -> build\lib.win-amd64-cpython-311\skimage\data\tests
#       copying skimage\data\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\data\tests
#       creating build\lib.win-amd64-cpython-311\skimage\draw\tests
#       copying skimage\draw\tests\test_draw.py -> build\lib.win-amd64-cpython-311\skimage\draw\tests
#       copying skimage\draw\tests\test_draw3d.py -> build\lib.win-amd64-cpython-311\skimage\draw\tests
#       copying skimage\draw\tests\test_draw_nd.py -> build\lib.win-amd64-cpython-311\skimage\draw\tests
#       copying skimage\draw\tests\test_polygon2mask.py -> build\lib.win-amd64-cpython-311\skimage\draw\tests
#       copying skimage\draw\tests\test_random_shapes.py -> build\lib.win-amd64-cpython-311\skimage\draw\tests
#       copying skimage\draw\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\draw\tests
#       creating build\lib.win-amd64-cpython-311\skimage\exposure\tests
#       copying skimage\exposure\tests\test_exposure.py -> build\lib.win-amd64-cpython-311\skimage\exposure\tests
#       copying skimage\exposure\tests\test_histogram_matching.py -> build\lib.win-amd64-cpython-311\skimage\exposure\tests
#       copying skimage\exposure\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\exposure\tests
#       creating build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_basic_features.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_blob.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_brief.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_canny.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_cascade.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_censure.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_corner.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_daisy.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_haar.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_hog.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_match.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_orb.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_peak.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_sift.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_template.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_texture.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\test_util.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       copying skimage\feature\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\feature\tests
#       creating build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\bilateral.py -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\generic.py -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\_percentile.py -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\__init__.py -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       creating build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_correlate.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_edges.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_fft_based.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_gabor.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_gaussian.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_lpi_filter.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_median.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_ridges.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_thresholding.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_unsharp_mask.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\test_window.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       copying skimage\filters\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\filters\tests
#       creating build\lib.win-amd64-cpython-311\skimage\filters\rank\tests
#       copying skimage\filters\rank\tests\test_rank.py -> build\lib.win-amd64-cpython-311\skimage\filters\rank\tests
#       copying skimage\filters\rank\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\filters\rank\tests
#       creating build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\graph_cut.py -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\graph_merge.py -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\rag.py -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\setup.py -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\_ncut.py -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\__init__.py -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       creating build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_anisotropy.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_connect.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_flexible.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_heap.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_mcp.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_pixel_graph.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\test_spath.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       copying skimage\graph\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\graph\tests
#       creating build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_collection.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_colormixer.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_fits.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_histograms.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_imageio.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_imread.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_io.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_mpl_imshow.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_multi_image.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_pil.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_plugin_util.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_sift.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_simpleitk.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\test_tifffile.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       copying skimage\io\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\io\tests
#       creating build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\fits_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\gdal_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\gtk_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\imageio_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\imread_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\matplotlib_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\pil_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\qt_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\q_color_mixer.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\q_histogram.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\simpleitk_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\skivi.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\tifffile_plugin.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\util.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\__init__.py -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       creating build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_block.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_blur_effect.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_ccomp.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_entropy.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_find_contours.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_fit.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_label.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_marching_cubes.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_moments.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_pnpoly.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_polygon.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_profile.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\test_regionprops.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       copying skimage\measure\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\measure\tests
#       creating build\lib.win-amd64-cpython-311\skimage\metrics\tests
#       copying skimage\metrics\tests\test_segmentation_metrics.py -> build\lib.win-amd64-cpython-311\skimage\metrics\tests
#       copying skimage\metrics\tests\test_set_metrics.py -> build\lib.win-amd64-cpython-311\skimage\metrics\tests
#       copying skimage\metrics\tests\test_simple_metrics.py -> build\lib.win-amd64-cpython-311\skimage\metrics\tests
#       copying skimage\metrics\tests\test_structural_similarity.py -> build\lib.win-amd64-cpython-311\skimage\metrics\tests
#       copying skimage\metrics\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\metrics\tests
#       creating build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_binary.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_convex_hull.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_extrema.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_flood_fill.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_footprints.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_gray.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_max_tree.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_misc.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_reconstruction.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_skeletonize.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_skeletonize_3d.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\test_util.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       copying skimage\morphology\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\morphology\tests
#       creating build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\test_denoise.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\test_inpaint.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\test_j_invariant.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\test_restoration.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\test_rolling_ball.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\test_unwrap.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       creating build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_active_contour_model.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_boundaries.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_chan_vese.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_clear_border.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_expand_labels.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_felzenszwalb.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_join.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_morphsnakes.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_quickshift.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_random_walker.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_slic.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\test_watershed.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       copying skimage\segmentation\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\segmentation\tests
#       creating build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_finite_radon_transform.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_geometric.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_hough_transform.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_integral.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_pyramids.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_radon_transform.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\test_warps.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       copying skimage\transform\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\transform\tests
#       creating build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_apply_parallel.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_arraycrop.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_compare.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_dtype.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_invert.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_labels.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_map_array.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_montage.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_random_noise.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_regular_grid.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_shape.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\test_unique_rows.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       copying skimage\util\tests\__init__.py -> build\lib.win-amd64-cpython-311\skimage\util\tests
#       creating build\lib.win-amd64-cpython-311\skimage\viewer\canvastools
#       copying skimage\viewer\canvastools\base.py -> build\lib.win-amd64-cpython-311\skimage\viewer\canvastools
#       copying skimage\viewer\canvastools\linetool.py -> build\lib.win-amd64-cpython-311\skimage\viewer\canvastools
#       copying skimage\viewer\canvastools\painttool.py -> build\lib.win-amd64-cpython-311\skimage\viewer\canvastools
#       copying skimage\viewer\canvastools\recttool.py -> build\lib.win-amd64-cpython-311\skimage\viewer\canvastools
# ...
#       copying skimage\registration\tests\data\OriginalX-130Y130.png -> build\lib.win-amd64-cpython-311\skimage\registration\tests\data
#       copying skimage\registration\tests\data\OriginalX130Y130.png -> build\lib.win-amd64-cpython-311\skimage\registration\tests\data
#       copying skimage\registration\tests\data\OriginalX75Y75.png -> build\lib.win-amd64-cpython-311\skimage\registration\tests\data
#       copying skimage\registration\tests\data\TransformedX-130Y130.png -> build\lib.win-amd64-cpython-311\skimage\registration\tests\data
#       copying skimage\registration\tests\data\TransformedX130Y130.png -> build\lib.win-amd64-cpython-311\skimage\registration\tests\data
#       copying skimage\registration\tests\data\TransformedX75Y75.png -> build\lib.win-amd64-cpython-311\skimage\registration\tests\data
#       copying skimage\restoration\_denoise_cy.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_denoise_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_inpaint.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_inpaint.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_nl_means_denoising.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_nl_means_denoising.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_rolling_ball_cy.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_rolling_ball_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_unwrap_1d.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_unwrap_1d.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_unwrap_2d.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_unwrap_2d.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_unwrap_3d.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\_unwrap_3d.pyx -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\unwrap_2d_ljmu.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\unwrap_2d_ljmu.h -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\unwrap_3d_ljmu.c -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\restoration\unwrap_3d_ljmu.h -> build\lib.win-amd64-cpython-311\skimage\restoration
#       copying skimage\scripts\skivi -> build\lib.win-amd64-cpython-311\skimage\scripts
#       copying skimage\segmentation\_felzenszwalb_cy.c -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_felzenszwalb_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_quickshift_cy.c -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_quickshift_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_slic.c -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_slic.pyx -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_watershed_cy.c -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\_watershed_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\heap_general.pxi -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\segmentation\heap_watershed.pxi -> build\lib.win-amd64-cpython-311\skimage\segmentation
#       copying skimage\transform\_hough_transform.c -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_hough_transform.pyx -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_radon_transform.c -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_radon_transform.pyx -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_warps_cy.c -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\transform\_warps_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\transform
#       copying skimage\util\_remap.cpp -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\util\_remap.pyx -> build\lib.win-amd64-cpython-311\skimage\util
#       copying skimage\_shared\fast_exp.c -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\fast_exp.h -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\fast_exp.pxd -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\fast_exp.pyx -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\fused_numerics.pxd -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\geometry.c -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\geometry.pxd -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\geometry.pyx -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\interpolation.c -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\interpolation.pxd -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\interpolation.pyx -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\transform.c -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\transform.pxd -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\transform.pyx -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\_shared\vectorized_ops.h -> build\lib.win-amd64-cpython-311\skimage\_shared
#       copying skimage\color\tests\ciede2000_test_data.txt -> build\lib.win-amd64-cpython-311\skimage\color\tests
#       creating build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_a_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_a_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_a_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_b_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_b_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_b_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_c_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_c_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_c_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d50_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d50_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d50_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d55_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d55_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d55_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d65_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d65_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d65_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d75_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_d75_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\lab_array_e_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_a_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_a_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_a_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_b_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_b_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_b_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_c_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_c_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_c_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d50_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d50_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d50_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d55_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d55_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d55_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d65_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d65_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d65_r.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d75_10.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_d75_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\color\tests\data\luv_array_e_2.npy -> build\lib.win-amd64-cpython-311\skimage\color\tests\data
#       copying skimage\filters\rank\bilateral_cy.c -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\bilateral_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\core_cy.c -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\core_cy.pxd -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\core_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\core_cy_3d.c -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\core_cy_3d.pxd -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\core_cy_3d.pyx -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\generic_cy.c -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\generic_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\percentile_cy.c -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\filters\rank\percentile_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\filters\rank
#       copying skimage\future\graph\_ncut_cy.c -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       copying skimage\future\graph\_ncut_cy.pyx -> build\lib.win-amd64-cpython-311\skimage\future\graph
#       creating build\lib.win-amd64-cpython-311\skimage\future\graph\tests
#       copying skimage\future\graph\tests\test_rag.py -> build\lib.win-amd64-cpython-311\skimage\future\graph\tests
#       copying skimage\io\_plugins\_colormixer.c -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\_colormixer.pyx -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\_histograms.c -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\_histograms.pyx -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\fits_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\gdal_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\gtk_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\imageio_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\imread_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\matplotlib_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\pil_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\qt_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\simpleitk_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\io\_plugins\tifffile_plugin.ini -> build\lib.win-amd64-cpython-311\skimage\io\_plugins
#       copying skimage\restoration\tests\camera_rl.npy -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\camera_unsup.npy -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\camera_unsup2.npy -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       copying skimage\restoration\tests\camera_wiener.npy -> build\lib.win-amd64-cpython-311\skimage\restoration\tests
#       running build_ext
#       INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       INFO: customize MSVCCompiler
#       INFO: customize MSVCCompiler using ConditionalOpenMP
#       INFO: CCompilerOpt.cc_test_flags[1077] : testing flags (/O2)
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       INFO: CCompilerOpt.cache_flush[857] : write cache to path -> C:\Users\homeuser\AppData\Local\Temp\pip-install-77rt0zxl\scikit-image_5815c097bdf048788edc4a1358d2e28f\build\temp.win-amd64-cpython-311\Release\ccompiler_opt_cache_ext.py
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-image
# ERROR: Could not build wheels for scikit-image, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from skimage.metrics import structural_similarity as ssim

# Assuming "original_slice" and "oblique_slice" are two 2D arrays of the same shape
# representing the intensity values of the two slices


# Assuming "original_slice" and "resampled_slice" are two 2D arrays of the same shape
# representing the intensity values of the two slices

# Compute the MSE between the two slices
original_slice = image[:, :, slice_index]
mse = np.mean((original_slice - filtered_image_2d) ** 2)

print(f"MSE: {mse}")

# Compute the SSIM between the two slices
ssim_value = ssim(original_slice, filtered_image_2d, gaussian_weights=False, channel_axis=None)

print(f"SSIM: {ssim_value}")

# Compute NCC between the two slices
re_sliced_image = filtered_image_2d
mu_original = np.mean(original_slice)
mu_re_sliced = np.mean(re_sliced_image)
sigma_original = np.std(original_slice)
sigma_re_sliced = np.std(re_sliced_image)

# Compute the normalized cross-correlation between the two slices
ncc = np.mean((original_slice - mu_original) * (re_sliced_image - mu_re_sliced)) / (sigma_original * sigma_re_sliced)

print("Normalized Cross Correlation:", ncc)

# Compute the peak signal-to-noise ratio
max_pixel = np.iinfo(original_slice.dtype).max

# Compute the peak signal-to-noise ratio
psnr = 20 * np.log10(max_pixel / np.sqrt(mse))

print(f"PSNR: {psnr}")

# Compute the dice coefficient between the two slices
# Compute the intersection and union of the two images
intersection = np.logical_and(original_slice, re_sliced_image)
union = np.logical_or(original_slice, re_sliced_image)

# Compute the Dice coefficient
dice = 2 * intersection.sum() / union.sum()

print("Dice Coefficient:", dice)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import numpy as np
# ----> 2 from skimage.metrics import structural_similarity as ssim
#       4 # Assuming "original_slice" and "oblique_slice" are two 2D arrays of the same shape
#       5 # representing the intensity values of the two slices
#       6
#    (...)
#      10
#      11 # Compute the MSE between the two slices
#      12 original_slice = image[:, :, slice_index]
#
# ModuleNotFoundError: No module named 'skimage'

# %% [markdown]
# ## Apply 3D filtering before re-slicing

# %% [markdown]
# ## 3D filtering

# %% [markdown]
# 1. What is the effect of increasing sigmaColor in bilateral filters?5, 20, 80
# 1. What is the effect of increasing sigmaSpace in bilateral filters?5, 20, 80

# %%
# Apply bilateral filter to image using bilateral_filter_3d
import numpy as np
import matplotlib.pyplot as plt

# Load image
image = np.load("test_trus.npy").T
print("Image shape:", image.shape)

# Apply bilateral filter to image using OpenCV
d = 3
sigmaColor = 5
sigmaSpace = 120
filtered_image_3d = bilateral_filter_3d(image[:, :, :3], d, sigmaColor, sigmaSpace)
plt.imshow(filtered_image_3d[:, :, 0], cmap='gray')
# Out:
# Image shape: (455, 325, 46)
# C:\Users\homeuser\AppData\Local\Temp\ipykernel_18648\2958091240.py:67: RuntimeWarning: overflow encountered in scalar subtract
#   intensity_distance = (center_pixel - neighbor_pixel)

# %% [markdown]
# ### Apply reslicing after 3D filtering

# %%
# Apply rotation at the centre of the slice
translation_points = (np.array(image[:, :, 0].shape) - 1)/2
rotation_angle = 45

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the 3D volume of the prostate glandprostate_volume = np.load("prostate_volume.npy")
# Load the 3D volume of the prostate gland
prostate_volume = filtered_image_3d

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Set the x, y, and z limits of the plot
x_len, y_len, z_len = prostate_volume.shape
ax.set_xlim(0, x_len)
ax.set_ylim(0, y_len)
ax.set_zlim(0, z_len)

# Define the transformation matrix for the oblique view
theta = np.deg2rad(0)
phi = np.deg2rad(-25)
slice_index = 0
# translation_matrix = np.array([[1, 0, -translation_points[0]],
#                                    [0, 1, -translation_points[1]],
#                                    [0, 0, 1]])
# rotation_matrix_theta = np.array([[np.cos(theta), -np.sin(theta), 0],
#                             [np.sin(theta), np.cos(theta), 0],
#                             [0, 0, 1]])
# rotation_matrix_phi = np.array([[1, 0, 0],
#                                    [0, np.cos(phi), -np.sin(phi)],
#                                    [0, np.sin(phi), np.cos(phi)]])
# # Then apply translation back to the original position
# translation_back_matrix = np.array([[1, 0, translation_points[0]],
#                                     [0, 1, translation_points[1]],
#                                     [0, 0, 1]])
# # Create a composed affine matrix
# rotation_matrix = np.matmul(translation_back_matrix, np.matmul(rotation_matrix_phi, np.matmul(rotation_matrix_theta, translation_matrix)))


rotation_matrix_theta = np.array([[np.cos(theta), -np.sin(theta), 0],
                            [np.sin(theta), np.cos(theta), 0],
                            [0, 0, 1]])
rotation_matrix_phi = np.array([[1, 0, 0],
                                   [0, np.cos(phi), -np.sin(phi)],
                                   [0, np.sin(phi), np.cos(phi)]])

# Create a composed affine matrix
rotation_matrix = np.matmul(rotation_matrix_phi, rotation_matrix_theta)


# Define the coordinates of the slice

xx, yy = np.meshgrid(np.arange(x_len), np.arange(y_len), indexing='ij')
zz = np.ones_like(xx) * slice_index


# Apply the transformation matrix to the coordinates
xyz = np.vstack((xx.flatten(), yy.flatten(), zz.flatten())).T
xyz = np.dot(xyz, rotation_matrix)

# Reshape the transformed coordinates and the slice values
xx, yy, zz = xyz[:, 0].reshape(xx.shape), xyz[:, 1].reshape(yy.shape), xyz[:, 2].reshape(zz.shape)



# Extract the slice values
slice_values = prostate_volume[:, :, slice_index]


# Interpolate the slice values to the transformed coordinates
slice_values = interpn((np.arange(x_len), np.arange(y_len)), slice_values, np.vstack((xx.flatten(), yy.flatten())).T, method='nearest', bounds_error=False, fill_value=None)

# Plot the transformed slice as a surface

# Create a 1D array of the slice values
color_values = slice_values.flatten()

# Create a 1D array of RGB colors corresponding to the intensity values
cmap = plt.cm.gray
norm = plt.Normalize(vmin=color_values.min(), vmax=color_values.max())
color_array = cmap(norm(color_values))

# Plot the transformed slice as a 3D scatter plot
ax.scatter(xx, yy, zz, c=color_array, s = 0.07)

# Calculate the minimum and maximum z-coordinates of the transformed slice
z_min = zz.min()
z_max = zz.max()
x_min = xx.min()
x_max = xx.max()
y_min = yy.min()
y_max = yy.max()

# Set the limits of the z-axis to include the entire slice
ax.set_zlim(z_min, z_max)
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)

# Set the title of the plot
ax.set_title("Oblique view of a prostate gland 3D volume slice")

# Set the labels for the x, y, and z axes
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

# Show the plot
plt.show()

# %% [markdown]
# 1. What is the effect of increasing sigmaColor in bilateral filters?5, 20, 80
# 1. What is the effect of increasing sigmaSpace in bilateral filters?5, 20, 80

# %%
# Create a 1D array of the slice values
# Fill in the blanks with 0s
xx3d = xx
yy3d = yy
plt.scatter(xx3d, yy3d, c=color_array, s = 0.07)
# Add title
plt.title("3D filtering | d = 3, sigmaColor = 5, sigmaSpace = 120")
# Save the figure
plt.savefig("3d_filtering_sigmaSpace_120.png")

# %% [markdown]
# ### Difference between the filtered then re-sliced image and the original image

# %%
import numpy as np
from skimage.metrics import structural_similarity as ssim
re_sliced_image = slice_values.reshape(xx.shape)
re_sliced_image.shape
# Assuming "original_slice" and "oblique_slice" are two 2D arrays of the same shape
# representing the intensity values of the two slices


# Assuming "original_slice" and "resampled_slice" are two 2D arrays of the same shape
# representing the intensity values of the two slices

# Compute the MSE between the two slices
original_slice = image[:, :, slice_index]
mse = np.mean((original_slice - re_sliced_image) ** 2)

print(f"MSE: {mse}")

# Compute the SSIM between the two slices
ssim_value = ssim(original_slice, re_sliced_image, gaussian_weights=False, channel_axis=None)

print(f"SSIM: {ssim_value}")

# Compute NCC between the two slices
mu_original = np.mean(original_slice)
mu_re_sliced = np.mean(re_sliced_image)
sigma_original = np.std(original_slice)
sigma_re_sliced = np.std(re_sliced_image)

# Compute the normalized cross-correlation between the two slices
ncc = np.mean((original_slice - mu_original) * (re_sliced_image - mu_re_sliced)) / (sigma_original * sigma_re_sliced)

print("Normalized Cross Correlation:", ncc)

# Compute the PSNR between the two slices
# Compute the maximum pixel value of the images
max_pixel = np.iinfo(original_slice.dtype).max

# Compute the peak signal-to-noise ratio
psnr = 20 * np.log10(max_pixel / np.sqrt(mse))

print(f"PSNR: {psnr}")

# Compute the dice coefficient between the two slices
# Compute the intersection and union of the two images
intersection = np.logical_and(original_slice, re_sliced_image)
union = np.logical_or(original_slice, re_sliced_image)

# Compute the Dice coefficient
dice = 2 * intersection.sum() / union.sum()

print("Dice Coefficient:", dice)
# Out:
# MSE: 1276.3652273879966
# SSIM: 0.2267854922536091
# Normalized Cross Correlation: 0.5483838941634162
# PSNR: 17.071053968719955
# Dice Coefficient: 1.5629149203047084
# /home/vscode/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:348: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   return func(*args, **kwargs)

# %%
#compute the PSNR between the two slices
10 * np.log10((255**2)/1284.09)
# Out:
# 17.04484896999888

# %%
import numpy as np

# Define the original image and the oblique slice
original_image = np.random.rand(256, 256)
oblique_slice = np.random.rand(256, 256)

# Compute the mean and standard deviation of each image
mu_original = np.mean(original_image)
sigma_original = np.std(original_image)
mu_oblique = np.mean(oblique_slice)
sigma_oblique = np.std(oblique_slice)

# Compute the normalized cross correlation between the two images
ncc = np.mean((original_image - mu_original) * (oblique_slice - mu_oblique)) / (sigma_original * sigma_oblique)

print("Normalized Cross Correlation:", ncc)
# Out:
# Normalized Cross Correlation: 1.0000000000000002

# %%
import numpy as np

# Define the original image and the oblique slice
original_image = np.random.rand(256, 256)
oblique_slice = np.random.rand(256, 256)

# Compute the maximum pixel value of the images
max_pixel = np.iinfo(original_image.dtype).max

# Compute the mean squared error between the two images
mse = np.mean((original_image - oblique_slice) ** 2)

# Compute the peak signal-to-noise ratio
psnr = 20 * np.log10(max_pixel / np.sqrt(mse))

print("Peak Signal-to-Noise Ratio:", psnr)
